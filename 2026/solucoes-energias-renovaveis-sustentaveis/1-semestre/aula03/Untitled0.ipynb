# %% [markdown]
# # **Atividade - Motores - SERS**
#
# objetivo:
# com base nos dados de placa de motores de indução(PU, n, FP), calcular as potências ativa, reativa e aparente(P, Q e S).

# %% [markdown]
# *1: Iserção dos dados do motor*

# %%
# Potência útil (Mecânica) ----> PU ----> em Watts
PU = int(input('Insira o valor da potência em Watts: '))
# Rendimento (de 0 a 1) ----> n
n = float(input('Insira o valor do rendimento (0 a 1): '))
# Fator de potência (DE 0 A 1) ----> FP (cosPhi)
FP = float(input('Insira o valor de potência (de 0 a 1): '))
# Out:
# Insira o valor da potência em Watts: 3000
# Insira o valor do rendimento (0 a 1): 0.76
# Insira o valor de potência (de 0 a 1): 0.80

# %%
PU, n, FP
# Out:
# (3000, 0.76, 0.8)

# %% [markdown]
# *2. Cálculo das potências ativa (P), aparente (S) e reativa (Q)*
#
# P = PU / n
# S = P /FP
# Q ----> teorema de Pitágoras

# %%
# Potência Ativa (P)
P = PU / n
# Potência Aparente (S)
S = P / FP
# Potência Reativa (Q)
# Exponenciação ----> **
# Raiz quadrada ----> ** 0.5
Q = (S**2 - P**2)**0.5

# %%
P, S, Q
# Out:
# (3947.3684210526317, 4934.210526315789, 2960.526315789473)

# %% [markdown]
# *3. Apresentação dos resultados *

# %%
print(f'A potência ativa será de {int(P)} W')
print(f'A potência aparente será de {int(S)} VA')
print(f'A potência reativa será de {int(P)} VAr')


# Exemplo para limitar o resultado em duas casas decimais
# print(f'A potência ativa será de {P:.2f}w')
# Out:
# A potência ativa será de 3947 W
# A potência aparente será de 4934 VA
# A potência reativa será de 3947 VAr

# %% [markdown]
# Exercício:
#
# Acesse as imagens das placas disponíveis na pasta da Aula 02 (16/03) e calcule as potências.
